// %%
var ROOT_PATH = "/home/node/notebook/src/open_digger"
var openDigger = require(ROOT_PATH)
var repoId = 22542759

// %% [markdown]
// 访问clickhouse，查看数据库

// %%
var query = openDigger.driver.clickhouse.query;
query(
    `SHOW DATABASES`
)
.then(res=>{
    console.log(res);
})
// Out:
// [
//   { name: '_temporary_and_external_tables' },
//   { name: 'default' },
//   { name: 'github_log' },
//   { name: 'system' }
// ]

// %% [markdown]
// 查看github_log数据库中有哪些表

// %%
//查看数据库有哪些表
query(
    `SHOW TABLES from github_log`
)
.then(res=>{
    console.log(res);
})
// Out:
// [ { name: 'events' } ]

// %% [markdown]
// 查看event表中的列名信息,跟期中的schema一致

// %%
query(
    `select distinct name from system.columns where database='github_log' and table='events'`
)
.then(res=>{
    console.log(res);
})
// Out:
// [
//   { name: 'id' },
//   { name: 'type' },
//   { name: 'action' },
//   { name: 'actor_id' },
//   { name: 'actor_login' },
//   { name: 'repo_id' },
//   { name: 'repo_name' },
//   { name: 'org_id' },
//   { name: 'org_login' },
//   { name: 'created_at' },
//   { name: 'issue_id' },
//   { name: 'issue_number' },
//   { name: 'issue_title' },
//   { name: 'body' },
//   { name: 'issue_labels.name' },
//   { name: 'issue_labels.color' },
//   { name: 'issue_labels.default' },
//   { name: 'issue_labels.description' },
//   { name: 'issue_author_id' },
//   { name: 'issue_author_login' },
//   { name: 'issue_author_type' },
//   { name: 'issue_author_association' },
//   { name: 'issue_assignee_id' },
//   { name: 'issue_assignee_login' },
//   { name: 'issue_assignees.login' },
//   { name: 'issue_assignees.id' },
//   { name: 'issue_created_at' },
//   { name: 'issue_updated_at' },
//   { name: 'issue_comments' },
//   { name: 'issue_closed_at' },
//   { name: 'issue_comment_id' },
//   { name: 'issue_comment_created_at' },
//   { name: 'issue_comment_updated_at' },
//   { name: 'issue_comment_author_association' },
//   { name: 'issue_comment_author_id' },
//   { name: 'issue_comment_author_login' },
//   { name: 'issue_comment_author_type' },
//   { name: 'pull_commits' },
//   { name: 'pull_additions' },
//   { name: 'pull_deletions' },
//   { name: 'pull_changed_files' },
//   { name: 'pull_merged' },
//   { name: 'pull_merge_commit_sha' },
//   { name: 'pull_merged_at' },
//   { name: 'pull_merged_by_id' },
//   { name: 'pull_merged_by_login' },
//   { name: 'pull_merged_by_type' },
//   { name: 'pull_requested_reviewer_id' },
//   { name: 'pull_requested_reviewer_login' },
//   { name: 'pull_requested_reviewer_type' },
//   { name: 'pull_review_comments' },
//   { name: 'repo_description' },
//   { name: 'repo_size' },
//   { name: 'repo_stargazers_count' },
//   { name: 'repo_forks_count' },
//   { name: 'repo_language' },
//   { name: 'repo_has_issues' },
//   { name: 'repo_has_projects' },
//   { name: 'repo_has_downloads' },
//   { name: 'repo_has_wiki' },
//   { name: 'repo_has_pages' },
//   { name: 'repo_license' },
//   { name: 'repo_default_branch' },
//   { name: 'repo_created_at' },
//   { name: 'repo_updated_at' },
//   { name: 'repo_pushed_at' },
//   { name: 'pull_review_id' },
//   { name: 'pull_review_comment_id' },
//   { name: 'pull_review_comment_path' },
//   { name: 'pull_review_comment_position' },
//   { name: 'pull_review_comment_author_id' },
//   { name: 'pull_review_comment_author_login' },
//   { name: 'pull_review_comment_author_type' },
//   { name: 'pull_review_comment_author_association' },
//   { name: 'pull_review_comment_created_at' },
//   { name: 'pull_review_comment_updated_at' },
//   { name: 'push_id' },
//   { name: 'push_size' },
//   { name: 'push_distinct_size' },
//   { name: 'push_ref' },
//   { name: 'push_head' },
//   { name: 'push_commits.name' },
//   { name: 'push_commits.email' },
//   { name: 'push_commits.message' },
//   { name: 'fork_forkee_id' },
//   { name: 'fork_forkee_full_name' },
//   { name: 'fork_forkee_owner_id' },
//   { name: 'fork_forkee_owner_login' },
//   { name: 'fork_forkee_owner_type' },
//   { name: 'delete_ref' },
//   { name: 'delete_ref_type' },
//   { name: 'delete_pusher_type' },
//   { name: 'create_ref' },
//   { name: 'create_ref_type' },
//   { name: 'create_master_branch' },
//   { name: 'create_description' },
//   { name: 'create_pusher_type' },
//   { name: 'gollum_pages.page_name' },
//   { name: 'gollum_pages.title' },
//   { name: 'gollum_pages.action' },
//   ... 32 more items
// ]

// %% [markdown]
// 查看有哪些类型的event

// %%
query(
    `select distinct(type) from github_log.events`
)
.then(res=>{
    console.log(res);
})
// Out:
// [
//   { type: 'CommitCommentEvent' },
//   { type: 'CreateEvent' },
//   { type: 'DeleteEvent' },
//   { type: 'ForkEvent' },
//   { type: 'GollumEvent' },
//   { type: 'IssueCommentEvent' },
//   { type: 'PushEvent' },
//   { type: 'IssuesEvent' },
//   { type: 'MemberEvent' },
//   { type: 'PullRequestEvent' },
//   { type: 'PullRequestReviewCommentEvent' },
//   { type: 'ReleaseEvent' },
//   { type: 'WatchEvent' },
//   { type: 'PublicEvent' }
// ]

// %% [markdown]
// # 每月新增 Star和Fork的个数

// %%
query(
    `select toYear(created_at) as year, toMonth(created_at) as month, repo_forks_count, repo_stargazers_count
     from github_log.events
     where id in
        (select max(id)
         from github_log.events where repo_id=22542759 
            and type in ('PullRequestEvent','PullRequestReviewCommentEvent')
            and toYear(created_at) < 2022
         group by(toYear(created_at), toMonth(created_at))
         )
    order by(year, month)`
).then(data => {
    var year = [], month = [], repoForkNum = [], repoStarNum = [], repoForkInc = [], repoStarInc = [];
    
    year = data.map(d => d.year);
    month = data.map(d => d.month);
    repoForkNum = data.map(d => d.repo_forks_count);
    repoStarNum = data.map(d => d.repo_stargazers_count);

    var xAxis = [];
    var tableList = [];

    for(var i=0; i<year.length; i++){
        xAxis.push(year[i]+'-'+month[i].toString().padStart(2, '0'));
        if(i) {
            repoForkInc.push(repoForkNum[i] - repoForkNum[i-1]);
            repoStarInc.push(repoStarNum[i] - repoStarNum[i-1]);        
        } else {
            repoForkInc.push(repoForkNum[i]);
            repoStarInc.push(repoStarNum[i]);        
        }
        tableList.push([xAxis[i], repoForkInc[i], repoStarInc[i]])

    }
    openDigger.render.plotly([
        {x: xAxis, y: repoForkInc, mode: 'scatter', name: 'Fork月增量'},
        {x: xAxis, y: repoStarInc, mode: 'scatter', name: 'Star月增量'}
    ], {
        title: 'cdapio/cdap项目自创建到归档期的Fork以及Star的月增量',
        xais: {type: 'category'}
    });
    console.table(tableList.map((l, i) => {
        return {
            '日期': l[0],
            'Fork月增量': l[1],
            'Star月增量': l[2]
        };
    
    }));
});
// Out:
// ┌─────────┬───────────┬────────────┬────────────┐
// │ (index) │   日期    │ Fork月增量 │ Star月增量 │
// ├─────────┼───────────┼────────────┼────────────┤
// │    0    │ '2015-01' │     8      │     22     │
// │    1    │ '2015-02' │     1      │     7      │
// │    2    │ '2015-03' │     1      │     10     │
// │    3    │ '2015-04' │     6      │     4      │
// │    4    │ '2015-05' │     1      │     7      │
// │    5    │ '2015-06' │     2      │     6      │
// │    6    │ '2015-07' │     0      │     2      │
// │    7    │ '2015-08' │     0      │     4      │
// │    8    │ '2015-09' │     2      │     9      │
// │    9    │ '2015-10' │     2      │     5      │
// │   10    │ '2015-11' │     4      │     8      │
// │   11    │ '2015-12' │     2      │     6      │
// │   12    │ '2016-01' │     2      │     8      │
// │   13    │ '2016-02' │     4      │     5      │
// │   14    │ '2016-03' │     1      │     5      │
// │   15    │ '2016-04' │     4      │     7      │
// │   16    │ '2016-05' │     3      │     6      │
// │   17    │ '2016-06' │     2      │     10     │
// │   18    │ '2016-07' │     4      │     6      │
// │   19    │ '2016-08' │     4      │     -2     │
// │   20    │ '2016-09' │     3      │     2      │
// │   21    │ '2016-10' │     5      │     3      │
// │   22    │ '2016-11' │     7      │     7      │
// │   23    │ '2016-12' │     2      │     7      │
// │   24    │ '2017-01' │     3      │     2      │
// │   25    │ '2017-02' │     2      │     5      │
// │   26    │ '2017-03' │     3      │     6      │
// │   27    │ '2017-04' │     3      │     6      │
// │   28    │ '2017-05' │     5      │     2      │
// │   29    │ '2017-06' │     6      │     4      │
// │   30    │ '2017-07' │     3      │     5      │
// │   31    │ '2017-08' │     5      │     3      │
// │   32    │ '2017-09' │     3      │     2      │
// │   33    │ '2017-10' │     2      │     5      │
// │   34    │ '2017-11' │     2      │     5      │
// │   35    │ '2017-12' │     1      │     7      │
// │   36    │ '2018-01' │     1      │     6      │
// │   37    │ '2018-02' │     2      │     3      │
// │   38    │ '2018-03' │     3      │     2      │
// │   39    │ '2018-04' │     2      │     3      │
// │   40    │ '2018-05' │     0      │     11     │
// │   41    │ '2018-06' │     4      │     5      │
// │   42    │ '2018-07' │     2      │     8      │
// │   43    │ '2018-08' │     4      │     14     │
// │   44    │ '2018-09' │     7      │     6      │
// │   45    │ '2018-10' │     5      │     3      │
// │   46    │ '2018-11' │     6      │     14     │
// │   47    │ '2018-12' │     4      │     2      │
// │   48    │ '2019-01' │     0      │     2      │
// │   49    │ '2019-02' │     6      │     5      │
// │   50    │ '2019-03' │     3      │     6      │
// │   51    │ '2019-04' │     4      │     24     │
// │   52    │ '2019-05' │     9      │     17     │
// │   53    │ '2019-06' │     8      │     6      │
// │   54    │ '2019-07' │     3      │     11     │
// │   55    │ '2019-08' │     3      │     4      │
// │   56    │ '2019-09' │     8      │     6      │
// │   57    │ '2019-10' │     4      │     11     │
// │   58    │ '2019-11' │     6      │     9      │
// │   59    │ '2019-12' │     5      │     7      │
// │   60    │ '2020-01' │     7      │     6      │
// │   61    │ '2020-02' │     3      │     10     │
// │   62    │ '2020-03' │     5      │     12     │
// │   63    │ '2020-04' │     6      │     8      │
// │   64    │ '2020-05' │     5      │     7      │
// │   65    │ '2020-06' │     2      │     12     │
// │   66    │ '2020-07' │     3      │     8      │
// │   67    │ '2020-08' │     3      │     6      │
// │   68    │ '2020-09' │     1      │     6      │
// │   69    │ '2020-10' │     0      │     7      │
// │   70    │ '2020-11' │     4      │     10     │
// │   71    │ '2020-12' │     5      │     6      │
// │   72    │ '2021-01' │     7      │     5      │
// │   73    │ '2021-02' │     -1     │     11     │
// │   74    │ '2021-03' │     6      │     7      │
// │   75    │ '2021-04' │     2      │     13     │
// │   76    │ '2021-05' │     3      │     8      │
// │   77    │ '2021-06' │     4      │     6      │
// │   78    │ '2021-07' │     3      │     13     │
// │   79    │ '2021-08' │     2      │     11     │
// │   80    │ '2021-09' │     3      │     11     │
// │   81    │ '2021-10' │     2      │     8      │
// │   82    │ '2021-11' │     5      │     6      │
// │   83    │ '2021-12' │     5      │     7      │
// └─────────┴───────────┴────────────┴────────────┘

// %% [markdown]
// # 3. 每月打开 PR 和合入 PR 的个数（注意，关闭 PR 不等于合入）

// %% [markdown]
// ## 3.1 每月打开PR的个数

// %%
//每月打开PR的个数
query(
    `select year, month, count(issue_id) AS PRCreateCount
    from
    (
        select toYear(issue_created_at) AS year, toMonth(issue_created_at) AS month, issue_id  
        from github_log.events
        where repo_id = 22542759
        and type = 'PullRequestEvent'
        and action = 'opened'
        and toYear(issue_created_at) < 2022
    )t1
    group by (year, month)
    order by (year, month)`
).then(data=> {
    var year = [], month = [], PRCreateCount = [];
    
    year = data.map(d => d.year);
    month = data.map(d => d.month);
    PRCreateCount = data.map(d => d.PRCreateCount);
    

    var xAxis = [];
    var tableList = [];
    for(var i=0; i<year.length; i++){
        xAxis.push(year[i]+'-'+month[i].toString().padStart(2, '0'));
        tableList.push([xAxis[i], PRCreateCount[i]])
    }
    openDigger.render.plotly([
        {x: xAxis, y: PRCreateCount, mode: 'scatter', name: 'PR打开月数量'}
    ], {
        title: 'cdapio/cdap项目自创建到2021期间每月打开PR的数量',
        xais: {type: 'category'}
    });
    console.table(tableList.map((l, i) => {
        return {
            '日期': l[0],
            'PR打开月量': l[1]
        }
    }));
});
// Out:
// ┌─────────┬───────────┬────────────┐
// │ (index) │   日期    │ PR打开月量 │
// ├─────────┼───────────┼────────────┤
// │    0    │ '2015-01' │   '296'    │
// │    1    │ '2015-02' │   '246'    │
// │    2    │ '2015-03' │   '410'    │
// │    3    │ '2015-04' │   '601'    │
// │    4    │ '2015-05' │   '339'    │
// │    5    │ '2015-06' │   '269'    │
// │    6    │ '2015-07' │   '420'    │
// │    7    │ '2015-08' │   '276'    │
// │    8    │ '2015-09' │   '444'    │
// │    9    │ '2015-10' │   '239'    │
// │   10    │ '2015-11' │   '197'    │
// │   11    │ '2015-12' │   '164'    │
// │   12    │ '2016-01' │   '254'    │
// │   13    │ '2016-02' │   '145'    │
// │   14    │ '2016-03' │   '243'    │
// │   15    │ '2016-04' │   '261'    │
// │   16    │ '2016-05' │   '134'    │
// │   17    │ '2016-06' │   '107'    │
// │   18    │ '2016-07' │   '314'    │
// │   19    │ '2016-08' │   '357'    │
// │   20    │ '2016-09' │   '233'    │
// │   21    │ '2016-10' │   '166'    │
// │   22    │ '2016-11' │   '187'    │
// │   23    │ '2016-12' │   '289'    │
// │   24    │ '2017-01' │   '248'    │
// │   25    │ '2017-02' │   '480'    │
// │   26    │ '2017-03' │   '222'    │
// │   27    │ '2017-04' │   '214'    │
// │   28    │ '2017-05' │   '302'    │
// │   29    │ '2017-06' │   '194'    │
// │   30    │ '2017-07' │   '132'    │
// │   31    │ '2017-08' │   '236'    │
// │   32    │ '2017-09' │   '131'    │
// │   33    │ '2017-10' │    '53'    │
// │   34    │ '2017-11' │    '57'    │
// │   35    │ '2017-12' │    '61'    │
// │   36    │ '2018-01' │    '46'    │
// │   37    │ '2018-02' │    '26'    │
// │   38    │ '2018-03' │    '65'    │
// │   39    │ '2018-04' │    '90'    │
// │   40    │ '2018-05' │    '34'    │
// │   41    │ '2018-06' │   '112'    │
// │   42    │ '2018-07' │   '192'    │
// │   43    │ '2018-08' │   '114'    │
// │   44    │ '2018-09' │   '108'    │
// │   45    │ '2018-10' │    '66'    │
// │   46    │ '2018-11' │    '27'    │
// │   47    │ '2018-12' │    '53'    │
// │   48    │ '2019-01' │    '76'    │
// │   49    │ '2019-02' │   '143'    │
// │   50    │ '2019-03' │   '100'    │
// │   51    │ '2019-04' │    '63'    │
// │   52    │ '2019-05' │    '91'    │
// │   53    │ '2019-06' │    '57'    │
// │   54    │ '2019-07' │    '45'    │
// │   55    │ '2019-08' │    '67'    │
// │   56    │ '2019-09' │    '90'    │
// │   57    │ '2019-10' │    '43'    │
// │   58    │ '2019-11' │    '45'    │
// │   59    │ '2019-12' │    '41'    │
// │   60    │ '2020-01' │    '35'    │
// │   61    │ '2020-02' │    '68'    │
// │   62    │ '2020-03' │   '119'    │
// │   63    │ '2020-04' │   '108'    │
// │   64    │ '2020-05' │    '93'    │
// │   65    │ '2020-06' │   '177'    │
// │   66    │ '2020-07' │   '127'    │
// │   67    │ '2020-08' │   '182'    │
// │   68    │ '2020-09' │    '52'    │
// │   69    │ '2020-10' │    '44'    │
// │   70    │ '2020-11' │    '42'    │
// │   71    │ '2020-12' │   '130'    │
// │   72    │ '2021-01' │    '91'    │
// │   73    │ '2021-02' │    '58'    │
// │   74    │ '2021-03' │   '159'    │
// │   75    │ '2021-04' │    '35'    │
// │   76    │ '2021-05' │    '79'    │
// │   77    │ '2021-06' │    '88'    │
// │   78    │ '2021-07' │    '73'    │
// │   79    │ '2021-08' │    '53'    │
// │   80    │ '2021-09' │    '19'    │
// │   81    │ '2021-10' │    '9'     │
// │   82    │ '2021-11' │    '38'    │
// │   83    │ '2021-12' │    '45'    │
// └─────────┴───────────┴────────────┘

// %% [markdown]
// ## 3.2 每月合入PR的个数

// %%
//每月合入PR的个数
query(
    `select year, month, count(issue_id) AS PRMergeCount
    from 
    (
        select toYear(pull_merged_at) AS year, toMonth(pull_merged_at) AS month, issue_id
        from github_log.events
        where repo_id = 22542759
            and type = 'PullRequestEvent'
            and pull_merged = 1
            and toYear(pull_merged_at) < 2022
    )t1
    group by (year, month)
    order by (year, month)`
).then(data=> {
    var year = [], month = [], PRMergeCount = [];
    year = data.map(d => d.year);
    month = data.map(d => d.month);
    PRMergeCount = data.map(d => d.PRMergeCount);
    

    var xAxis = [];
    var tableList = [];
    for(var i=0; i<year.length; i++){
        xAxis.push(year[i]+'-'+month[i].toString().padStart(2, '0'));
        tableList.push([xAxis[i], PRMergeCount[i]])
    }
    openDigger.render.plotly([
        {x: xAxis, y: PRMergeCount, mode: 'scatter', name: 'PR合并月数量'}
    ], {
        title: 'cdapio/cdap项目自创建到2021期间每月合并PR的数量',
        xais: {type: 'category'}
    });
    console.table(tableList.map((l, i) => {
        return {
            '日期': l[0],
            'PR合入月量': l[1]
        }
    }));
})
// Out:
// ┌─────────┬───────────┬────────────┐
// │ (index) │   日期    │ PR合入月量 │
// ├─────────┼───────────┼────────────┤
// │    0    │ '2015-01' │   '275'    │
// │    1    │ '2015-02' │   '203'    │
// │    2    │ '2015-03' │   '367'    │
// │    3    │ '2015-04' │   '551'    │
// │    4    │ '2015-05' │   '312'    │
// │    5    │ '2015-06' │   '254'    │
// │    6    │ '2015-07' │   '373'    │
// │    7    │ '2015-08' │   '256'    │
// │    8    │ '2015-09' │   '416'    │
// │    9    │ '2015-10' │   '210'    │
// │   10    │ '2015-11' │   '191'    │
// │   11    │ '2015-12' │   '147'    │
// │   12    │ '2016-01' │   '239'    │
// │   13    │ '2016-02' │   '130'    │
// │   14    │ '2016-03' │   '230'    │
// │   15    │ '2016-04' │   '251'    │
// │   16    │ '2016-05' │   '107'    │
// │   17    │ '2016-06' │    '97'    │
// │   18    │ '2016-07' │   '289'    │
// │   19    │ '2016-08' │   '328'    │
// │   20    │ '2016-09' │   '229'    │
// │   21    │ '2016-10' │   '156'    │
// │   22    │ '2016-11' │   '180'    │
// │   23    │ '2016-12' │   '281'    │
// │   24    │ '2017-01' │   '214'    │
// │   25    │ '2017-02' │   '460'    │
// │   26    │ '2017-03' │   '179'    │
// │   27    │ '2017-04' │   '217'    │
// │   28    │ '2017-05' │   '282'    │
// │   29    │ '2017-06' │   '181'    │
// │   30    │ '2017-07' │   '115'    │
// │   31    │ '2017-08' │   '237'    │
// │   32    │ '2017-09' │   '130'    │
// │   33    │ '2017-10' │    '44'    │
// │   34    │ '2017-11' │    '55'    │
// │   35    │ '2017-12' │    '67'    │
// │   36    │ '2018-01' │    '40'    │
// │   37    │ '2018-02' │    '30'    │
// │   38    │ '2018-03' │    '61'    │
// │   39    │ '2018-04' │    '89'    │
// │   40    │ '2018-05' │    '31'    │
// │   41    │ '2018-06' │    '91'    │
// │   42    │ '2018-07' │   '191'    │
// │   43    │ '2018-08' │   '100'    │
// │   44    │ '2018-09' │   '128'    │
// │   45    │ '2018-10' │    '57'    │
// │   46    │ '2018-11' │    '25'    │
// │   47    │ '2018-12' │    '45'    │
// │   48    │ '2019-01' │    '84'    │
// │   49    │ '2019-02' │   '126'    │
// │   50    │ '2019-03' │   '107'    │
// │   51    │ '2019-04' │    '52'    │
// │   52    │ '2019-05' │    '84'    │
// │   53    │ '2019-06' │    '45'    │
// │   54    │ '2019-07' │    '41'    │
// │   55    │ '2019-08' │    '63'    │
// │   56    │ '2019-09' │    '89'    │
// │   57    │ '2019-10' │    '30'    │
// │   58    │ '2019-11' │    '36'    │
// │   59    │ '2019-12' │    '31'    │
// │   60    │ '2020-01' │    '26'    │
// │   61    │ '2020-02' │    '41'    │
// │   62    │ '2020-03' │   '110'    │
// │   63    │ '2020-04' │    '98'    │
// │   64    │ '2020-05' │    '83'    │
// │   65    │ '2020-06' │   '167'    │
// │   66    │ '2020-07' │    '95'    │
// │   67    │ '2020-08' │   '156'    │
// │   68    │ '2020-09' │    '56'    │
// │   69    │ '2020-10' │    '33'    │
// │   70    │ '2020-11' │    '33'    │
// │   71    │ '2020-12' │   '128'    │
// │   72    │ '2021-01' │    '88'    │
// │   73    │ '2021-02' │    '56'    │
// │   74    │ '2021-03' │   '149'    │
// │   75    │ '2021-04' │    '27'    │
// │   76    │ '2021-05' │    '57'    │
// │   77    │ '2021-06' │    '86'    │
// │   78    │ '2021-07' │    '65'    │
// │   79    │ '2021-08' │    '56'    │
// │   80    │ '2021-09' │    '12'    │
// │   81    │ '2021-10' │    '9'     │
// │   82    │ '2021-11' │    '21'    │
// │   83    │ '2021-12' │    '27'    │
// └─────────┴───────────┴────────────┘

// %% [markdown]
// # 7. Issue和PR从打开到第一次有人回复（非本人回复）的平均时长和中位数（单位：天）

// %% [markdown]
// ## 7.1 Issue从打开到第一次有人回复（非本人回复）的平均时长和中位数（单位：天）

// %%
query(
    `select avg(dateDiff('day', create_time, comment_time))As average, quantile(dateDiff('day', create_time, comment_time)) AS median
    from 
    (select min(issue_comment_created_at) AS comment_time, min(issue_created_at) AS create_time
        from github_log.events
        where repo_id = 22542759
        and type = 'IssueCommentEvent'
        and issue_comment_author_id <> issue_author_id
        group by issue_id)t2`
).then(data => {console.log(data)});
// Out:
// [ { average: 1.772310610051628, median: 0 } ]

// %% [markdown]
// ## 7.2 PR从打开到第一次有人回复（非本人回复）的平均时长和中位数（单位：天）

// %%
query(
    `select avg(dateDiff('day', create_time, comment_time))As average, quantile(dateDiff('day', create_time, comment_time)) AS median
    from
        (select issue_id, issue_created_at AS create_time
        from github_log.events
        where repo_id = 22542759
        and type = 'PullRequestEvent'
        and action = 'opened'
        and toYear(issue_created_at)<2022)t1, 
        (select issue_id, min(pull_review_comment_created_at) AS comment_time
        from github_log.events
        where repo_id = 22542759
        and type = 'PullRequestReviewCommentEvent'
        and issue_author_id <> pull_review_comment_author_id
        and toYear(pull_review_comment_created_at) < 2022
        group by issue_id)t2
    where t1.issue_id = t2.issue_id
`
).then(data => {console.log(data)});
// Out:
// [ { average: 1.216278101582015, median: 0 } ]
