// %%
var openDigger = require('../src/open_digger');

// %%
var query = openDigger.driver.clickhouse.query;
query(    
    `SHOW DATABASES`
)
    .then(res=>{    
    console.log(res);
})
// Out:
// [
//   { name: '_temporary_and_external_tables' },
//   { name: 'default' },
//   { name: 'github_log' },
//   { name: 'system' }
// ]

// %%
query(    
    `SHOW TABLES from github_log`
)
    .then(res=>{    
    console.log(res);
})
// Out:
// [ { name: 'events' } ]

// %%
//展示表结构
query(    
    `DESC TABLE github_log.events`
)
    .then(res=>{    
    console.log(res);
})
// Out:
// [
//   {
//     name: 'id',
//     type: 'UInt64',
//     default_type: '',
//     default_expression: '',
//     comment: '',
//     codec_expression: '',
//     ttl_expression: ''
//   },
//   {
//     name: 'type',
//     type: "Enum8('CommitCommentEvent' = 1, 'CreateEvent' = 2, 'DeleteEvent' = 3, 'ForkEvent' = 4, 'GollumEvent' = 5, 'IssueCommentEvent' = 6, 'IssuesEvent' = 7, 'MemberEvent' = 8, 'PublicEvent' = 9, 'PullRequestEvent' = 10, 'PullRequestReviewCommentEvent' = 11, 'PushEvent' = 12, 'ReleaseEvent' = 13, 'WatchEvent' = 14, 'PullRequestReviewEvent' = 15)",
//     default_type: '',
//     default_expression: '',
//     comment: '',
//     codec_expression: '',
//     ttl_expression: ''
//   },
//   {
//     name: 'action',
//     type: "Enum8('added' = 1, 'closed' = 2, 'created' = 3, 'labeled' = 4, 'opened' = 5, 'published' = 6, 'reopened' = 7, 'started' = 8)",
//     default_type: '',
//     default_expression: '',
//     comment: '',
//     codec_expression: '',
//     ttl_expression: ''
//   },
//   {
//     name: 'actor_id',
//     type: 'UInt64',
//     default_type: '',
//     default_expression: '',
//     comment: '',
//     codec_expression: '',
//     ttl_expression: ''
//   },
//   {
//     name: 'actor_login',
//     type: 'LowCardinality(String)',
//     default_type: '',
//     default_expression: '',
//     comment: '',
//     codec_expression: '',
//     ttl_expression: ''
//   },
//   {
//     name: 'repo_id',
//     type: 'UInt64',
//     default_type: '',
//     default_expression: '',
//     comment: '',
//     codec_expression: '',
//     ttl_expression: ''
//   },
//   {
//     name: 'repo_name',
//     type: 'LowCardinality(String)',
//     default_type: '',
//     default_expression: '',
//     comment: '',
//     codec_expression: '',
//     ttl_expression: ''
//   },
//   {
//     name: 'org_id',
//     type: 'UInt64',
//     default_type: '',
//     default_expression: '',
//     comment: '',
//     codec_expression: '',
//     ttl_expression: ''
//   },
//   {
//     name: 'org_login',
//     type: 'LowCardinality(String)',
//     default_type: '',
//     default_expression: '',
//     comment: '',
//     codec_expression: '',
//     ttl_expression: ''
//   },
//   {
//     name: 'created_at',
//     type: 'DateTime',
//     default_type: '',
//     default_expression: '',
//     comment: '',
//     codec_expression: '',
//     ttl_expression: ''
//   },
//   {
//     name: 'issue_id',
//     type: 'UInt64',
//     default_type: '',
//     default_expression: '',
//     comment: '',
//     codec_expression: '',
//     ttl_expression: ''
//   },
//   {
//     name: 'issue_number',
//     type: 'UInt32',
//     default_type: '',
//     default_expression: '',
//     comment: '',
//     codec_expression: '',
//     ttl_expression: ''
//   },
//   {
//     name: 'issue_title',
//     type: 'String',
//     default_type: '',
//     default_expression: '',
//     comment: '',
//     codec_expression: '',
//     ttl_expression: ''
//   },
//   {
//     name: 'body',
//     type: 'String',
//     default_type: '',
//     default_expression: '',
//     comment: '',
//     codec_expression: '',
//     ttl_expression: ''
//   },
//   {
//     name: 'issue_labels.name',
//     type: 'Array(String)',
//     default_type: '',
//     default_expression: '',
//     comment: '',
//     codec_expression: '',
//     ttl_expression: ''
//   },
//   {
//     name: 'issue_labels.color',
//     type: 'Array(String)',
//     default_type: '',
//     default_expression: '',
//     comment: '',
//     codec_expression: '',
//     ttl_expression: ''
//   },
//   {
//     name: 'issue_labels.default',
//     type: 'Array(UInt8)',
//     default_type: '',
//     default_expression: '',
//     comment: '',
//     codec_expression: '',
//     ttl_expression: ''
//   },
//   {
//     name: 'issue_labels.description',
//     type: 'Array(String)',
//     default_type: '',
//     default_expression: '',
//     comment: '',
//     codec_expression: '',
//     ttl_expression: ''
//   },
//   {
//     name: 'issue_author_id',
//     type: 'UInt64',
//     default_type: '',
//     default_expression: '',
//     comment: '',
//     codec_expression: '',
//     ttl_expression: ''
//   },
//   {
//     name: 'issue_author_login',
//     type: 'LowCardinality(String)',
//     default_type: '',
//     default_expression: '',
//     comment: '',
//     codec_expression: '',
//     ttl_expression: ''
//   },
//   {
//     name: 'issue_author_type',
//     type: "Enum8('Bot' = 1, 'Mannequin' = 2, 'Organization' = 3, 'User' = 4)",
//     default_type: '',
//     default_expression: '',
//     comment: '',
//     codec_expression: '',
//     ttl_expression: ''
//   },
//   {
//     name: 'issue_author_association',
//     type: "Enum8('COLLABORATOR' = 1, 'CONTRIBUTOR' = 2, 'MEMBER' = 3, 'NONE' = 4, 'OWNER' = 5, 'MANNEQUIN' = 6)",
//     default_type: '',
//     default_expression: '',
//     comment: '',
//     codec_expression: '',
//     ttl_expression: ''
//   },
//   {
//     name: 'issue_assignee_id',
//     type: 'UInt64',
//     default_type: '',
//     default_expression: '',
//     comment: '',
//     codec_expression: '',
//     ttl_expression: ''
//   },
//   {
//     name: 'issue_assignee_login',
//     type: 'LowCardinality(String)',
//     default_type: '',
//     default_expression: '',
//     comment: '',
//     codec_expression: '',
//     ttl_expression: ''
//   },
//   {
//     name: 'issue_assignees.login',
//     type: 'Array(LowCardinality(String))',
//     default_type: '',
//     default_expression: '',
//     comment: '',
//     codec_expression: '',
//     ttl_expression: ''
//   },
//   {
//     name: 'issue_assignees.id',
//     type: 'Array(UInt64)',
//     default_type: '',
//     default_expression: '',
//     comment: '',
//     codec_expression: '',
//     ttl_expression: ''
//   },
//   {
//     name: 'issue_created_at',
//     type: 'Nullable(DateTime)',
//     default_type: '',
//     default_expression: '',
//     comment: '',
//     codec_expression: '',
//     ttl_expression: ''
//   },
//   {
//     name: 'issue_updated_at',
//     type: 'Nullable(DateTime)',
//     default_type: '',
//     default_expression: '',
//     comment: '',
//     codec_expression: '',
//     ttl_expression: ''
//   },
//   {
//     name: 'issue_comments',
//     type: 'UInt16',
//     default_type: '',
//     default_expression: '',
//     comment: '',
//     codec_expression: '',
//     ttl_expression: ''
//   },
//   {
//     name: 'issue_closed_at',
//     type: 'Nullable(DateTime)',
//     default_type: '',
//     default_expression: '',
//     comment: '',
//     codec_expression: '',
//     ttl_expression: ''
//   },
//   {
//     name: 'issue_comment_id',
//     type: 'UInt64',
//     default_type: '',
//     default_expression: '',
//     comment: '',
//     codec_expression: '',
//     ttl_expression: ''
//   },
//   {
//     name: 'issue_comment_created_at',
//     type: 'Nullable(DateTime)',
//     default_type: '',
//     default_expression: '',
//     comment: '',
//     codec_expression: '',
//     ttl_expression: ''
//   },
//   {
//     name: 'issue_comment_updated_at',
//     type: 'Nullable(DateTime)',
//     default_type: '',
//     default_expression: '',
//     comment: '',
//     codec_expression: '',
//     ttl_expression: ''
//   },
//   {
//     name: 'issue_comment_author_association',
//     type: "Enum8('COLLABORATOR' = 1, 'CONTRIBUTOR' = 2, 'MEMBER' = 3, 'NONE' = 4, 'OWNER' = 5, 'MANNEQUIN' = 6)",
//     default_type: '',
//     default_expression: '',
//     comment: '',
//     codec_expression: '',
//     ttl_expression: ''
//   },
//   {
//     name: 'issue_comment_author_id',
//     type: 'UInt64',
//     default_type: '',
//     default_expression: '',
//     comment: '',
//     codec_expression: '',
//     ttl_expression: ''
//   },
//   {
//     name: 'issue_comment_author_login',
//     type: 'LowCardinality(String)',
//     default_type: '',
//     default_expression: '',
//     comment: '',
//     codec_expression: '',
//     ttl_expression: ''
//   },
//   {
//     name: 'issue_comment_author_type',
//     type: "Enum8('Bot' = 1, 'Mannequin' = 2, 'Organization' = 3, 'User' = 4)",
//     default_type: '',
//     default_expression: '',
//     comment: '',
//     codec_expression: '',
//     ttl_expression: ''
//   },
//   {
//     name: 'pull_commits',
//     type: 'UInt16',
//     default_type: '',
//     default_expression: '',
//     comment: '',
//     codec_expression: '',
//     ttl_expression: ''
//   },
//   {
//     name: 'pull_additions',
//     type: 'UInt16',
//     default_type: '',
//     default_expression: '',
//     comment: '',
//     codec_expression: '',
//     ttl_expression: ''
//   },
//   {
//     name: 'pull_deletions',
//     type: 'UInt16',
//     default_type: '',
//     default_expression: '',
//     comment: '',
//     codec_expression: '',
//     ttl_expression: ''
//   },
//   {
//     name: 'pull_changed_files',
//     type: 'UInt32',
//     default_type: '',
//     default_expression: '',
//     comment: '',
//     codec_expression: '',
//     ttl_expression: ''
//   },
//   {
//     name: 'pull_merged',
//     type: 'UInt8',
//     default_type: '',
//     default_expression: '',
//     comment: '',
//     codec_expression: '',
//     ttl_expression: ''
//   },
//   {
//     name: 'pull_merge_commit_sha',
//     type: 'String',
//     default_type: '',
//     default_expression: '',
//     comment: '',
//     codec_expression: '',
//     ttl_expression: ''
//   },
//   {
//     name: 'pull_merged_at',
//     type: 'Nullable(DateTime)',
//     default_type: '',
//     default_expression: '',
//     comment: '',
//     codec_expression: '',
//     ttl_expression: ''
//   },
//   {
//     name: 'pull_merged_by_id',
//     type: 'UInt64',
//     default_type: '',
//     default_expression: '',
//     comment: '',
//     codec_expression: '',
//     ttl_expression: ''
//   },
//   {
//     name: 'pull_merged_by_login',
//     type: 'LowCardinality(String)',
//     default_type: '',
//     default_expression: '',
//     comment: '',
//     codec_expression: '',
//     ttl_expression: ''
//   },
//   {
//     name: 'pull_merged_by_type',
//     type: "Enum8('Bot' = 1, 'Mannequin' = 2, 'Organization' = 3, 'User' = 4)",
//     default_type: '',
//     default_expression: '',
//     comment: '',
//     codec_expression: '',
//     ttl_expression: ''
//   },
//   {
//     name: 'pull_requested_reviewer_id',
//     type: 'UInt64',
//     default_type: '',
//     default_expression: '',
//     comment: '',
//     codec_expression: '',
//     ttl_expression: ''
//   },
//   {
//     name: 'pull_requested_reviewer_login',
//     type: 'LowCardinality(String)',
//     default_type: '',
//     default_expression: '',
//     comment: '',
//     codec_expression: '',
//     ttl_expression: ''
//   },
//   {
//     name: 'pull_requested_reviewer_type',
//     type: "Enum8('Bot' = 1, 'Mannequin' = 2, 'Organization' = 3, 'User' = 4)",
//     default_type: '',
//     default_expression: '',
//     comment: '',
//     codec_expression: '',
//     ttl_expression: ''
//   },
//   {
//     name: 'pull_review_comments',
//     type: 'UInt16',
//     default_type: '',
//     default_expression: '',
//     comment: '',
//     codec_expression: '',
//     ttl_expression: ''
//   },
//   {
//     name: 'repo_description',
//     type: 'String',
//     default_type: '',
//     default_expression: '',
//     comment: '',
//     codec_expression: '',
//     ttl_expression: ''
//   },
//   {
//     name: 'repo_size',
//     type: 'UInt32',
//     default_type: '',
//     default_expression: '',
//     comment: '',
//     codec_expression: '',
//     ttl_expression: ''
//   },
//   {
//     name: 'repo_stargazers_count',
//     type: 'UInt32',
//     default_type: '',
//     default_expression: '',
//     comment: '',
//     codec_expression: '',
//     ttl_expression: ''
//   },
//   {
//     name: 'repo_forks_count',
//     type: 'UInt32',
//     default_type: '',
//     default_expression: '',
//     comment: '',
//     codec_expression: '',
//     ttl_expression: ''
//   },
//   {
//     name: 'repo_language',
//     type: 'String',
//     default_type: '',
//     default_expression: '',
//     comment: '',
//     codec_expression: '',
//     ttl_expression: ''
//   },
//   {
//     name: 'repo_has_issues',
//     type: 'UInt8',
//     default_type: '',
//     default_expression: '',
//     comment: '',
//     codec_expression: '',
//     ttl_expression: ''
//   },
//   {
//     name: 'repo_has_projects',
//     type: 'UInt8',
//     default_type: '',
//     default_expression: '',
//     comment: '',
//     codec_expression: '',
//     ttl_expression: ''
//   },
//   {
//     name: 'repo_has_downloads',
//     type: 'UInt8',
//     default_type: '',
//     default_expression: '',
//     comment: '',
//     codec_expression: '',
//     ttl_expression: ''
//   },
//   {
//     name: 'repo_has_wiki',
//     type: 'UInt8',
//     default_type: '',
//     default_expression: '',
//     comment: '',
//     codec_expression: '',
//     ttl_expression: ''
//   },
//   {
//     name: 'repo_has_pages',
//     type: 'UInt8',
//     default_type: '',
//     default_expression: '',
//     comment: '',
//     codec_expression: '',
//     ttl_expression: ''
//   },
//   {
//     name: 'repo_license',
//     type: 'String',
//     default_type: '',
//     default_expression: '',
//     comment: '',
//     codec_expression: '',
//     ttl_expression: ''
//   },
//   {
//     name: 'repo_default_branch',
//     type: 'String',
//     default_type: '',
//     default_expression: '',
//     comment: '',
//     codec_expression: '',
//     ttl_expression: ''
//   },
//   {
//     name: 'repo_created_at',
//     type: 'Nullable(DateTime)',
//     default_type: '',
//     default_expression: '',
//     comment: '',
//     codec_expression: '',
//     ttl_expression: ''
//   },
//   {
//     name: 'repo_updated_at',
//     type: 'Nullable(DateTime)',
//     default_type: '',
//     default_expression: '',
//     comment: '',
//     codec_expression: '',
//     ttl_expression: ''
//   },
//   {
//     name: 'repo_pushed_at',
//     type: 'Nullable(DateTime)',
//     default_type: '',
//     default_expression: '',
//     comment: '',
//     codec_expression: '',
//     ttl_expression: ''
//   },
//   {
//     name: 'pull_review_id',
//     type: 'UInt64',
//     default_type: '',
//     default_expression: '',
//     comment: '',
//     codec_expression: '',
//     ttl_expression: ''
//   },
//   {
//     name: 'pull_review_comment_id',
//     type: 'UInt64',
//     default_type: '',
//     default_expression: '',
//     comment: '',
//     codec_expression: '',
//     ttl_expression: ''
//   },
//   {
//     name: 'pull_review_comment_path',
//     type: 'String',
//     default_type: '',
//     default_expression: '',
//     comment: '',
//     codec_expression: '',
//     ttl_expression: ''
//   },
//   {
//     name: 'pull_review_comment_position',
//     type: 'String',
//     default_type: '',
//     default_expression: '',
//     comment: '',
//     codec_expression: '',
//     ttl_expression: ''
//   },
//   {
//     name: 'pull_review_comment_author_id',
//     type: 'UInt64',
//     default_type: '',
//     default_expression: '',
//     comment: '',
//     codec_expression: '',
//     ttl_expression: ''
//   },
//   {
//     name: 'pull_review_comment_author_login',
//     type: 'LowCardinality(String)',
//     default_type: '',
//     default_expression: '',
//     comment: '',
//     codec_expression: '',
//     ttl_expression: ''
//   },
//   {
//     name: 'pull_review_comment_author_type',
//     type: "Enum8('Bot' = 1, 'Mannequin' = 2, 'Organization' = 3, 'User' = 4)",
//     default_type: '',
//     default_expression: '',
//     comment: '',
//     codec_expression: '',
//     ttl_expression: ''
//   },
//   {
//     name: 'pull_review_comment_author_association',
//     type: "Enum8('COLLABORATOR' = 1, 'CONTRIBUTOR' = 2, 'MEMBER' = 3, 'NONE' = 4, 'OWNER' = 5, 'MANNEQUIN' = 6)",
//     default_type: '',
//     default_expression: '',
//     comment: '',
//     codec_expression: '',
//     ttl_expression: ''
//   },
//   {
//     name: 'pull_review_comment_created_at',
//     type: 'Nullable(DateTime)',
//     default_type: '',
//     default_expression: '',
//     comment: '',
//     codec_expression: '',
//     ttl_expression: ''
//   },
//   {
//     name: 'pull_review_comment_updated_at',
//     type: 'Nullable(DateTime)',
//     default_type: '',
//     default_expression: '',
//     comment: '',
//     codec_expression: '',
//     ttl_expression: ''
//   },
//   {
//     name: 'push_id',
//     type: 'UInt64',
//     default_type: '',
//     default_expression: '',
//     comment: '',
//     codec_expression: '',
//     ttl_expression: ''
//   },
//   {
//     name: 'push_size',
//     type: 'UInt32',
//     default_type: '',
//     default_expression: '',
//     comment: '',
//     codec_expression: '',
//     ttl_expression: ''
//   },
//   {
//     name: 'push_distinct_size',
//     type: 'UInt32',
//     default_type: '',
//     default_expression: '',
//     comment: '',
//     codec_expression: '',
//     ttl_expression: ''
//   },
//   {
//     name: 'push_ref',
//     type: 'String',
//     default_type: '',
//     default_expression: '',
//     comment: '',
//     codec_expression: '',
//     ttl_expression: ''
//   },
//   {
//     name: 'push_head',
//     type: 'String',
//     default_type: '',
//     default_expression: '',
//     comment: '',
//     codec_expression: '',
//     ttl_expression: ''
//   },
//   {
//     name: 'push_commits.name',
//     type: 'Array(LowCardinality(String))',
//     default_type: '',
//     default_expression: '',
//     comment: '',
//     codec_expression: '',
//     ttl_expression: ''
//   },
//   {
//     name: 'push_commits.email',
//     type: 'Array(String)',
//     default_type: '',
//     default_expression: '',
//     comment: '',
//     codec_expression: '',
//     ttl_expression: ''
//   },
//   {
//     name: 'push_commits.message',
//     type: 'Array(String)',
//     default_type: '',
//     default_expression: '',
//     comment: '',
//     codec_expression: '',
//     ttl_expression: ''
//   },
//   {
//     name: 'fork_forkee_id',
//     type: 'UInt64',
//     default_type: '',
//     default_expression: '',
//     comment: '',
//     codec_expression: '',
//     ttl_expression: ''
//   },
//   {
//     name: 'fork_forkee_full_name',
//     type: 'LowCardinality(String)',
//     default_type: '',
//     default_expression: '',
//     comment: '',
//     codec_expression: '',
//     ttl_expression: ''
//   },
//   {
//     name: 'fork_forkee_owner_id',
//     type: 'UInt64',
//     default_type: '',
//     default_expression: '',
//     comment: '',
//     codec_expression: '',
//     ttl_expression: ''
//   },
//   {
//     name: 'fork_forkee_owner_login',
//     type: 'LowCardinality(String)',
//     default_type: '',
//     default_expression: '',
//     comment: '',
//     codec_expression: '',
//     ttl_expression: ''
//   },
//   {
//     name: 'fork_forkee_owner_type',
//     type: "Enum8('Bot' = 1, 'Mannequin' = 2, 'Organization' = 3, 'User' = 4)",
//     default_type: '',
//     default_expression: '',
//     comment: '',
//     codec_expression: '',
//     ttl_expression: ''
//   },
//   {
//     name: 'delete_ref',
//     type: 'String',
//     default_type: '',
//     default_expression: '',
//     comment: '',
//     codec_expression: '',
//     ttl_expression: ''
//   },
//   {
//     name: 'delete_ref_type',
//     type: 'String',
//     default_type: '',
//     default_expression: '',
//     comment: '',
//     codec_expression: '',
//     ttl_expression: ''
//   },
//   {
//     name: 'delete_pusher_type',
//     type: "Enum8('deploy_key' = 1, 'user' = 2)",
//     default_type: '',
//     default_expression: '',
//     comment: '',
//     codec_expression: '',
//     ttl_expression: ''
//   },
//   {
//     name: 'create_ref',
//     type: 'String',
//     default_type: '',
//     default_expression: '',
//     comment: '',
//     codec_expression: '',
//     ttl_expression: ''
//   },
//   {
//     name: 'create_ref_type',
//     type: "Enum8('branch' = 1, 'tag' = 2)",
//     default_type: '',
//     default_expression: '',
//     comment: '',
//     codec_expression: '',
//     ttl_expression: ''
//   },
//   {
//     name: 'create_master_branch',
//     type: 'String',
//     default_type: '',
//     default_expression: '',
//     comment: '',
//     codec_expression: '',
//     ttl_expression: ''
//   },
//   {
//     name: 'create_description',
//     type: 'String',
//     default_type: '',
//     default_expression: '',
//     comment: '',
//     codec_expression: '',
//     ttl_expression: ''
//   },
//   {
//     name: 'create_pusher_type',
//     type: "Enum8('deploy_key' = 1, 'user' = 2)",
//     default_type: '',
//     default_expression: '',
//     comment: '',
//     codec_expression: '',
//     ttl_expression: ''
//   },
//   {
//     name: 'gollum_pages.page_name',
//     type: 'Array(String)',
//     default_type: '',
//     default_expression: '',
//     comment: '',
//     codec_expression: '',
//     ttl_expression: ''
//   },
//   {
//     name: 'gollum_pages.title',
//     type: 'Array(String)',
//     default_type: '',
//     default_expression: '',
//     comment: '',
//     codec_expression: '',
//     ttl_expression: ''
//   },
//   {
//     name: 'gollum_pages.action',
//     type: 'Array(String)',
//     default_type: '',
//     default_expression: '',
//     comment: '',
//     codec_expression: '',
//     ttl_expression: ''
//   },
//   ... 32 more items
// ]

// %%
//该项目在2018.11进行了一次项目名称的变更
query(    
    `select distinct repo_name,toYYYYMM(created_at) 
    from github_log.events where repo_id=22542759`  
)
    .then(res=>{    
    console.log(res);
})
// Out:
// [
//   { repo_name: 'caskdata/cdap', 'toYYYYMM(created_at)': 201501 },
//   { repo_name: 'caskdata/cdap', 'toYYYYMM(created_at)': 201502 },
//   { repo_name: 'caskdata/cdap', 'toYYYYMM(created_at)': 201503 },
//   { repo_name: 'caskdata/cdap', 'toYYYYMM(created_at)': 201504 },
//   { repo_name: 'caskdata/cdap', 'toYYYYMM(created_at)': 201505 },
//   { repo_name: 'caskdata/cdap', 'toYYYYMM(created_at)': 201506 },
//   { repo_name: 'caskdata/cdap', 'toYYYYMM(created_at)': 201507 },
//   { repo_name: 'caskdata/cdap', 'toYYYYMM(created_at)': 201508 },
//   { repo_name: 'caskdata/cdap', 'toYYYYMM(created_at)': 201509 },
//   { repo_name: 'caskdata/cdap', 'toYYYYMM(created_at)': 201510 },
//   { repo_name: 'caskdata/cdap', 'toYYYYMM(created_at)': 201511 },
//   { repo_name: 'caskdata/cdap', 'toYYYYMM(created_at)': 201512 },
//   { repo_name: 'caskdata/cdap', 'toYYYYMM(created_at)': 201601 },
//   { repo_name: 'caskdata/cdap', 'toYYYYMM(created_at)': 201602 },
//   { repo_name: 'caskdata/cdap', 'toYYYYMM(created_at)': 201603 },
//   { repo_name: 'caskdata/cdap', 'toYYYYMM(created_at)': 201604 },
//   { repo_name: 'caskdata/cdap', 'toYYYYMM(created_at)': 201605 },
//   { repo_name: 'caskdata/cdap', 'toYYYYMM(created_at)': 201606 },
//   { repo_name: 'caskdata/cdap', 'toYYYYMM(created_at)': 201607 },
//   { repo_name: 'caskdata/cdap', 'toYYYYMM(created_at)': 201608 },
//   { repo_name: 'caskdata/cdap', 'toYYYYMM(created_at)': 201609 },
//   { repo_name: 'caskdata/cdap', 'toYYYYMM(created_at)': 201610 },
//   { repo_name: 'caskdata/cdap', 'toYYYYMM(created_at)': 201611 },
//   { repo_name: 'caskdata/cdap', 'toYYYYMM(created_at)': 201612 },
//   { repo_name: 'caskdata/cdap', 'toYYYYMM(created_at)': 201701 },
//   { repo_name: 'caskdata/cdap', 'toYYYYMM(created_at)': 201702 },
//   { repo_name: 'caskdata/cdap', 'toYYYYMM(created_at)': 201703 },
//   { repo_name: 'caskdata/cdap', 'toYYYYMM(created_at)': 201704 },
//   { repo_name: 'caskdata/cdap', 'toYYYYMM(created_at)': 201705 },
//   { repo_name: 'caskdata/cdap', 'toYYYYMM(created_at)': 201706 },
//   { repo_name: 'caskdata/cdap', 'toYYYYMM(created_at)': 201707 },
//   { repo_name: 'caskdata/cdap', 'toYYYYMM(created_at)': 201708 },
//   { repo_name: 'caskdata/cdap', 'toYYYYMM(created_at)': 201709 },
//   { repo_name: 'caskdata/cdap', 'toYYYYMM(created_at)': 201710 },
//   { repo_name: 'caskdata/cdap', 'toYYYYMM(created_at)': 201711 },
//   { repo_name: 'caskdata/cdap', 'toYYYYMM(created_at)': 201712 },
//   { repo_name: 'caskdata/cdap', 'toYYYYMM(created_at)': 201801 },
//   { repo_name: 'caskdata/cdap', 'toYYYYMM(created_at)': 201802 },
//   { repo_name: 'caskdata/cdap', 'toYYYYMM(created_at)': 201803 },
//   { repo_name: 'caskdata/cdap', 'toYYYYMM(created_at)': 201804 },
//   { repo_name: 'caskdata/cdap', 'toYYYYMM(created_at)': 201805 },
//   { repo_name: 'caskdata/cdap', 'toYYYYMM(created_at)': 201806 },
//   { repo_name: 'caskdata/cdap', 'toYYYYMM(created_at)': 201807 },
//   { repo_name: 'caskdata/cdap', 'toYYYYMM(created_at)': 201808 },
//   { repo_name: 'caskdata/cdap', 'toYYYYMM(created_at)': 201809 },
//   { repo_name: 'caskdata/cdap', 'toYYYYMM(created_at)': 201810 },
//   { repo_name: 'caskdata/cdap', 'toYYYYMM(created_at)': 201811 },
//   { repo_name: 'cdapio/cdap', 'toYYYYMM(created_at)': 201811 },
//   { repo_name: 'cdapio/cdap', 'toYYYYMM(created_at)': 201812 },
//   { repo_name: 'cdapio/cdap', 'toYYYYMM(created_at)': 201901 },
//   { repo_name: 'cdapio/cdap', 'toYYYYMM(created_at)': 201902 },
//   { repo_name: 'cdapio/cdap', 'toYYYYMM(created_at)': 201903 },
//   { repo_name: 'cdapio/cdap', 'toYYYYMM(created_at)': 201904 },
//   { repo_name: 'cdapio/cdap', 'toYYYYMM(created_at)': 201905 },
//   { repo_name: 'cdapio/cdap', 'toYYYYMM(created_at)': 201906 },
//   { repo_name: 'cdapio/cdap', 'toYYYYMM(created_at)': 201907 },
//   { repo_name: 'cdapio/cdap', 'toYYYYMM(created_at)': 201908 },
//   { repo_name: 'cdapio/cdap', 'toYYYYMM(created_at)': 201909 },
//   { repo_name: 'cdapio/cdap', 'toYYYYMM(created_at)': 201910 },
//   { repo_name: 'cdapio/cdap', 'toYYYYMM(created_at)': 201911 },
//   { repo_name: 'cdapio/cdap', 'toYYYYMM(created_at)': 201912 },
//   { repo_name: 'cdapio/cdap', 'toYYYYMM(created_at)': 202001 },
//   { repo_name: 'cdapio/cdap', 'toYYYYMM(created_at)': 202002 },
//   { repo_name: 'cdapio/cdap', 'toYYYYMM(created_at)': 202003 },
//   { repo_name: 'cdapio/cdap', 'toYYYYMM(created_at)': 202004 },
//   { repo_name: 'cdapio/cdap', 'toYYYYMM(created_at)': 202005 },
//   { repo_name: 'cdapio/cdap', 'toYYYYMM(created_at)': 202006 },
//   { repo_name: 'cdapio/cdap', 'toYYYYMM(created_at)': 202007 },
//   { repo_name: 'cdapio/cdap', 'toYYYYMM(created_at)': 202008 },
//   { repo_name: 'cdapio/cdap', 'toYYYYMM(created_at)': 202009 },
//   { repo_name: 'cdapio/cdap', 'toYYYYMM(created_at)': 202010 },
//   { repo_name: 'cdapio/cdap', 'toYYYYMM(created_at)': 202011 },
//   { repo_name: 'cdapio/cdap', 'toYYYYMM(created_at)': 202012 },
//   { repo_name: 'cdapio/cdap', 'toYYYYMM(created_at)': 202101 },
//   { repo_name: 'cdapio/cdap', 'toYYYYMM(created_at)': 202102 },
//   { repo_name: 'cdapio/cdap', 'toYYYYMM(created_at)': 202103 },
//   { repo_name: 'cdapio/cdap', 'toYYYYMM(created_at)': 202104 },
//   { repo_name: 'cdapio/cdap', 'toYYYYMM(created_at)': 202105 },
//   { repo_name: 'cdapio/cdap', 'toYYYYMM(created_at)': 202106 },
//   { repo_name: 'cdapio/cdap', 'toYYYYMM(created_at)': 202107 },
//   { repo_name: 'cdapio/cdap', 'toYYYYMM(created_at)': 202108 },
//   { repo_name: 'cdapio/cdap', 'toYYYYMM(created_at)': 202109 },
//   { repo_name: 'cdapio/cdap', 'toYYYYMM(created_at)': 202110 },
//   { repo_name: 'cdapio/cdap', 'toYYYYMM(created_at)': 202111 },
//   { repo_name: 'cdapio/cdap', 'toYYYYMM(created_at)': 202112 },
//   { repo_name: 'cdapio/cdap', 'toYYYYMM(created_at)': 202201 },
//   { repo_name: 'cdapio/cdap', 'toYYYYMM(created_at)': 202202 },
//   { repo_name: 'cdapio/cdap', 'toYYYYMM(created_at)': 202203 },
//   { repo_name: 'cdapio/cdap', 'toYYYYMM(created_at)': 202204 },
//   { repo_name: 'cdapio/cdap', 'toYYYYMM(created_at)': 202205 },
//   { repo_name: 'cdapio/cdap', 'toYYYYMM(created_at)': 202206 }
// ]

// %%
//事件类型
query(    
    `select distinct type
    from github_log.events where repo_id=22542759`  
)
    .then(res=>{    
    console.log(res);    
})
// Out:
// [
//   { type: 'CommitCommentEvent' },
//   { type: 'CreateEvent' },
//   { type: 'DeleteEvent' },
//   { type: 'ForkEvent' },
//   { type: 'IssueCommentEvent' },
//   { type: 'PullRequestEvent' },
//   { type: 'PushEvent' },
//   { type: 'PullRequestReviewCommentEvent' },
//   { type: 'ReleaseEvent' },
//   { type: 'WatchEvent' },
//   { type: 'MemberEvent' }
// ]

// %%
//4-曲线图
query(   
        `select count(distinct actor_id) AS actor_id_count,toYYYYMM(created_at) AS month
                from github_log.events
                where repo_id=22542759
                and month < 202201
                group by month
                order by month`
        
).then(data=>{    
    var activeCount=[],yMonth=[];
    data.forEach(item=>{yMonth.push(item.month);activeCount.push(item.actor_id_count);})    
    openDigger.render.plotly([{x: yMonth, y: activeCount, mode: 'scatter', name: '用户数量'}],
                             {title: '每月在仓库中活跃的不同开发者总数',xaxis: {type: 'category'}});
})

// %%
//4-表格
query(   
        `select count(distinct actor_id) AS actor_id_count,toYYYYMM(created_at) AS month
                from github_log.events
                where repo_id=22542759
                and month <202201
                group by month
                order by month`
        
).then(data=>{
    var list=[];
    data.forEach(item=>{
            list.push(item);
    });
    console.table(list.map((p, i) => {
        return {
            '月份': p.month,
            '该月仓库中活跃的不同开发者总数': p.actor_id_count
             };
    }))
})
// Out:
// ┌─────────┬────────┬────────────────────────────────┐
// │ (index) │  月份  │ 该月仓库中活跃的不同开发者总数 │
// ├─────────┼────────┼────────────────────────────────┤
// │    0    │ 201501 │              '27'              │
// │    1    │ 201502 │              '32'              │
// │    2    │ 201503 │              '37'              │
// │    3    │ 201504 │              '37'              │
// │    4    │ 201505 │              '36'              │
// │    5    │ 201506 │              '36'              │
// │    6    │ 201507 │              '33'              │
// │    7    │ 201508 │              '32'              │
// │    8    │ 201509 │              '32'              │
// │    9    │ 201510 │              '27'              │
// │   10    │ 201511 │              '32'              │
// │   11    │ 201512 │              '28'              │
// │   12    │ 201601 │              '28'              │
// │   13    │ 201602 │              '29'              │
// │   14    │ 201603 │              '29'              │
// │   15    │ 201604 │              '32'              │
// │   16    │ 201605 │              '33'              │
// │   17    │ 201606 │              '34'              │
// │   18    │ 201607 │              '43'              │
// │   19    │ 201608 │              '37'              │
// │   20    │ 201609 │              '33'              │
// │   21    │ 201610 │              '35'              │
// │   22    │ 201611 │              '37'              │
// │   23    │ 201612 │              '35'              │
// │   24    │ 201701 │              '38'              │
// │   25    │ 201702 │              '39'              │
// │   26    │ 201703 │              '42'              │
// │   27    │ 201704 │              '40'              │
// │   28    │ 201705 │              '37'              │
// │   29    │ 201706 │              '44'              │
// │   30    │ 201707 │              '32'              │
// │   31    │ 201708 │              '36'              │
// │   32    │ 201709 │              '26'              │
// │   33    │ 201710 │              '24'              │
// │   34    │ 201711 │              '25'              │
// │   35    │ 201712 │              '29'              │
// │   36    │ 201801 │              '23'              │
// │   37    │ 201802 │              '22'              │
// │   38    │ 201803 │              '25'              │
// │   39    │ 201804 │              '22'              │
// │   40    │ 201805 │              '28'              │
// │   41    │ 201806 │              '25'              │
// │   42    │ 201807 │              '31'              │
// │   43    │ 201808 │              '31'              │
// │   44    │ 201809 │              '27'              │
// │   45    │ 201810 │              '24'              │
// │   46    │ 201811 │              '35'              │
// │   47    │ 201812 │              '20'              │
// │   48    │ 201901 │              '16'              │
// │   49    │ 201902 │              '26'              │
// │   50    │ 201903 │              '32'              │
// │   51    │ 201904 │              '45'              │
// │   52    │ 201905 │              '45'              │
// │   53    │ 201906 │              '37'              │
// │   54    │ 201907 │              '36'              │
// │   55    │ 201908 │              '31'              │
// │   56    │ 201909 │              '30'              │
// │   57    │ 201910 │              '28'              │
// │   58    │ 201911 │              '31'              │
// │   59    │ 201912 │              '29'              │
// │   60    │ 202001 │              '32'              │
// │   61    │ 202002 │              '33'              │
// │   62    │ 202003 │              '38'              │
// │   63    │ 202004 │              '34'              │
// │   64    │ 202005 │              '39'              │
// │   65    │ 202006 │              '35'              │
// │   66    │ 202007 │              '39'              │
// │   67    │ 202008 │              '36'              │
// │   68    │ 202009 │              '23'              │
// │   69    │ 202010 │              '25'              │
// │   70    │ 202011 │              '28'              │
// │   71    │ 202012 │              '35'              │
// │   72    │ 202101 │              '30'              │
// │   73    │ 202102 │              '36'              │
// │   74    │ 202103 │              '38'              │
// │   75    │ 202104 │              '39'              │
// │   76    │ 202105 │              '38'              │
// │   77    │ 202106 │              '32'              │
// │   78    │ 202107 │              '38'              │
// │   79    │ 202108 │              '33'              │
// │   80    │ 202109 │              '29'              │
// │   81    │ 202110 │              '21'              │
// │   82    │ 202111 │              '33'              │
// │   83    │ 202112 │              '39'              │
// └─────────┴────────┴────────────────────────────────┘

// %%
//4-曲线图2
query(   
        `select count(distinct actor_id) AS actor_id_count,toMonth(created_at) AS month
                from github_log.events
                where repo_id=22542759
                and month < 2022
                group by month
                order by month`
        
).then(data=>{    
    var activeCount=[],yMonth=[];
    data.forEach(item=>{yMonth.push(item.month);activeCount.push(item.actor_id_count);})    
    openDigger.render.plotly([{x: yMonth, y: activeCount, mode: 'scatter', name: '用户数量'}],
                             {title: '每月在仓库中活跃的不同开发者总数',xaxis: {type: 'category'}});
})

// %%
//4-表格2
query(   
        `select count(distinct actor_id) AS actor_id_count,toMonth(created_at) AS month
                from github_log.events
                where repo_id=22542759
                and month <202201
                group by month
                order by month`
        
).then(data=>{
    var list=[];
    data.forEach(item=>{
            list.push(item);
    });
    console.table(list.map((p, i) => {
        return {
            '月份': p.month,
            '该月仓库中活跃的不同开发者总数': p.actor_id_count
             };
    }))
})
// Out:
// ┌─────────┬──────┬────────────────────────────────┐
// │ (index) │ 月份 │ 该月仓库中活跃的不同开发者总数 │
// ├─────────┼──────┼────────────────────────────────┤
// │    0    │  1   │             '144'              │
// │    1    │  2   │             '162'              │
// │    2    │  3   │             '174'              │
// │    3    │  4   │             '185'              │
// │    4    │  5   │             '196'              │
// │    5    │  6   │             '156'              │
// │    6    │  7   │             '160'              │
// │    7    │  8   │             '144'              │
// │    8    │  9   │             '129'              │
// │    9    │  10  │             '115'              │
// │   10    │  11  │             '149'              │
// │   11    │  12  │             '143'              │
// └─────────┴──────┴────────────────────────────────┘

// %%
//6添加平均数、中位数
query(
           `select issue_number,dateDiff('day',issue_created_at,pull_merged_at) AS length
                from github_log.events
                where repo_id=22542759 
                and type='PullRequestEvent'
                and pull_merged = 1
                and toYYYYMM(pull_merged_at)<202201
            `
).then(data=>{
    var list=[];
    data.forEach(item=>{
            list.push(Number(item.length))
    });
    
    list.sort();
    var mid_value,mid_index,sum,average;
    mid_index=list.length/2;
    sum=0;
    if(list.length%2==0){         
        mid_value=(list[mid_index]+list[mid_index+1])/2;
    }else{
        mid_index=(list.length-1)/2;
        mid_value=list[mid_index];
    }
    for(var i=0;i<list.length;i++){
        sum+=list[i];
    }
    average=sum/list.length;
    // console.log(list.length);
    // console.log(mid_index);
    //console.log('sum'+sum);
    console.log('average:'+average);
    console.log('mid_value:'+mid_value);
});
// Out:
// average:2.4766540317022745
// mid_value:1

// %%
//7-issue
query(
       `select issue_number,min(dateDiff('day',issue_created_at,issue_comment_created_at)) AS length      
           from github_log.events 
                where repo_id=22542759
                and type in ('IssueCommentEvent')
                and issue_author_id <> issue_comment_author_id
                and toYYYYMM(issue_comment_created_at)<202201
                group by issue_number
            `
).then(data=>{
    var list=[];
    data.forEach(item=>{
            list.push(Number(item.length))
    });
    
    list.sort();
    var mid_value,mid_index,sum,average;
    mid_index=list.length/2;
    sum=0;
    if(list.length%2==0){         
        mid_value=(list[mid_index]+list[mid_index+1])/2;
    }else{
        mid_index=(list.length-1)/2;
        mid_value=list[mid_index];
    }
    for(var i=0;i<list.length;i++){
        sum+=list[i];
    }
    average=sum/list.length;
    //console.log(list);
    //console.log("sum"+sum);
    console.log('average:'+average);
    console.log('mid_value:'+mid_value);
});
// Out:
// average:1.8720748829953198
// mid_value:0

// %%
//7-pr
query(`select issue_number as pr_number,min(dateDiff('day',issue_created_at,pull_review_comment_created_at))  AS length    
           from github_log.events
                where repo_id=22542759
                and type in ('PullRequestReviewCommentEvent')
                and pull_review_comment_author_id <> issue_author_id
                and toYYYYMM(pull_review_comment_created_at)<202201
                group by issue_number`
).then(data=>{
    var list=[];
    data.forEach(item=>{
            list.push(Number(item.length))
    });
    
    list.sort();
    var mid_value,mid_index,sum,average;
    mid_index=list.length/2;
    sum=0;
    if(list.length%2==0){         
        mid_value=(list[mid_index]+list[mid_index+1])/2;
    }else{
        mid_index=(list.length-1)/2;
        mid_value=list[mid_index];
    }
    for(var i=0;i<list.length;i++){
        sum+=list[i];
    }
    average=sum/list.length;
    //console.log(list);
    //console.log("sum"+sum);
    console.log('average:'+average);
    console.log('mid_value:'+mid_value);
});
// Out:
// average:1.262749898000816
// mid_value:0

// %%
//各事件的不同活跃开发者数量变化
query(
    `select count(distinct actor_id) as number,type,toYear(created_at) as year from github_log.events
        where repo_id=22542759
        and year<2022
        group by year,type
        order by year`
).then(data=>{    
    var list_DeleteEvent=[],list_PullRequestReviewCommentEvent=[],list_CommitCommentEvent=[],list_ForkEvent=[],list_ReleaseEvent=[];
    var list_PushEvent=[],list_CreateEvent=[],list_IssueCommentEvent=[],list_WatchEvent=[],list_PullRequestEvent=[];
    var x_axis=[2015,2016,2017,2018,2019,2020,2021];
    data.forEach(item=>{
            switch(item.type){
                case 'DeleteEvent':list_DeleteEvent.push(Number(item.number));break;
                case 'PullRequestReviewCommentEvent':list_PullRequestReviewCommentEvent.push(Number(item.number));break;
                case 'CommitCommentEvent':list_CommitCommentEvent.push(Number(item.number));break;
                case 'ForkEvent':list_ForkEvent.push(Number(item.number));break;
                case 'ReleaseEvent':list_ReleaseEvent.push(Number(item.number));break;
                case 'PushEvent':list_PushEvent.push(Number(item.number));break;
                case 'CreateEvent':list_CreateEvent.push(Number(item.number));break;
                case 'IssueCommentEvent':list_IssueCommentEvent.push(Number(item.number));break;
                case 'WatchEvent':list_WatchEvent.push(Number(item.number));break;
                case 'PullRequestEvent':list_PullRequestEvent.push(Number(item.number));break;
            }
    });
    openDigger.render.plotly([{x: x_axis, y: list_DeleteEvent, mode: 'scatter', name: 'DeleteEvent用户数量'},
                             {x: x_axis, y: list_PullRequestReviewCommentEvent, mode: 'scatter', name: 'PullRequestReviewCommentEvent用户数量'},
                             {x: x_axis, y: list_CommitCommentEvent, mode: 'scatter', name: 'CommitCommentEvent用户数量'},
                             {x: x_axis, y: list_ForkEvent, mode: 'scatter', name: 'ForkEvent用户数量'},
                             {x: x_axis, y: list_ReleaseEvent, mode: 'scatter', name: 'ReleaseEvent用户数量'},
                             {x: x_axis, y: list_PushEvent, mode: 'scatter', name: 'PushEvent用户数量'},
                             {x: x_axis, y: list_CreateEvent, mode: 'scatter', name: 'CreateEvent用户数量'},
                             {x: x_axis, y: list_IssueCommentEvent, mode: 'scatter', name: 'IssueCommentEvent用户数量'},
                             {x: x_axis, y: list_WatchEvent, mode: 'scatter', name: 'WatchEvent用户数量'},
                             {x: x_axis, y: list_PullRequestEvent, mode: 'scatter', name: 'PullRequestEvent用户数量'}],
                             {title: '各事件的不同活跃开发者数量变化',xaxis: {type: 'category'}});
})
